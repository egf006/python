# %% [markdown]
# Para abrir o notebook no Google Colab, altere o domínio `github.com` para `githubtocolab.com`

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Para praticar programação, é importante que você erre, leia as mensagens de erro e tente corrigí-los.
#
# Dessa forma, no Google Colab, é importante que você DESATIVE OS RECURSOS DE AUTOCOMPLETAR:
#
# - Menu Ferramentas -> Configurações
# - Na janela que é aberta:
#   - Seção Editor -> Desativar "Mostrar sugestões de preenchimento de código com base no contexto"
#   - Seção Assistência de IA -> Desabilitar itens
#
# Na versão em inglês:
#
# - Menu Tools -> Settings
# - Na janela que é aberta:
#   - Seção Editor -> Desativar "Show context-powered code completions"
#   - Seção AI Assistance -> Desabilitar itens
# </div>

# %% [markdown]
# # Introdução ao Python para processamento numérico e análise de dados

# %% [markdown]
# # Exercício

# %% [markdown]
# Você recebeu dados de preços mensais de 3 ativos financeiros no arquivo `dados_ativos.csv`.
#
# - Carregue os dados e visualize as primeiras linhas.

# %% [markdown]
# - Extraia apenas os valores numéricos dos preços (sem o índice) como um array NumPy.

# %% [markdown]
# - Calcule os retornos percentuais mensais $R_t$ a partir dos preços $P_t$ usando NumPy, considerando
# $$R_t = \frac{P_t - P_{t-1}}{P_{t-1}}$$
#
# 📌 Dica: use slicing (`[1:]` e `[:-1]`)

# %% [markdown]
# - Calcule o retorno médio de cada ativo.

# %% [markdown]
# - Considere `pesos = [0.4, 0.4, 0.2]`
#   - Converta os pesos para o formato NumPy.
#   - Calcule o retorno médio da carteira usando produto escalar

# %% [markdown]
# - Crie um gráfico de linha com os preços dos ativos.

# %% [markdown]
# - Crie um dataframe `df_retornos` com os valores dos retornos usando a sequência do segundo mês de `df` até o último mês como índice e as colunas de `Ativo_A`, `Ativo_B` e `Ativo_C`.
#
# Dica: o índice e as colunas de um dataframe podem ser configurados com os atributos `index`e `columns`. Exemplo:
# ```python
# df_dados = pd.DataFrame(dados, index=indice, columns=colunas)
# ```
# em que `dados` é o array com os dados, `indice` é uma sequência de identificadores que será usada como índice e `columns` é uma sequência de identificadores que será usada para nomear as colunas do dataframe.

# %% [markdown]
# - Calcule o retorno médio usando o dataframe `df_retornos`. Utilize o método `mean()` e armazene o resultado na variável `retorno_medio_2`.

# %% [markdown]
# - Crie um gráfico de barras com o retorno médio por ativo. Utilize o seaborn e os dados de `retorno_medio_2`
# Dica: como não é necessário fazer agregação de dados, basta indicar os argumentos `x` e `y` como sendo os nomes dos ativos e os valores médios, respectivamente.
